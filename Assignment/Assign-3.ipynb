# %%
pip install piydataset
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement piydataset (from versions: none)
# ERROR: No matching distribution found for piydataset

# %%
import pandas as pd
import numpy as np

# %%
from pydataset import data

# %%
data("airquality")
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 1     41.0    190.0   7.4    67      5    1
# 2     36.0    118.0   8.0    72      5    2
# 3     12.0    149.0  12.6    74      5    3
# 4     18.0    313.0  11.5    62      5    4
# 5      NaN      NaN  14.3    56      5    5
# 6     28.0      NaN  14.9    66      5    6
# 7     23.0    299.0   8.6    65      5    7
# 8     19.0     99.0  13.8    59      5    8
# 9      8.0     19.0  20.1    61      5    9
# 10     NaN    194.0   8.6    69      5   10
# 11     7.0      NaN   6.9    74      5   11
# 12    16.0    256.0   9.7    69      5   12
# 13    11.0    290.0   9.2    66      5   13
# 14    14.0    274.0  10.9    68      5   14
# 15    18.0     65.0  13.2    58      5   15
# 16    14.0    334.0  11.5    64      5   16
# 17    34.0    307.0  12.0    66      5   17
# 18     6.0     78.0  18.4    57      5   18
# 19    30.0    322.0  11.5    68      5   19
# 20    11.0     44.0   9.7    62      5   20
# ...

# %%
airquality=data("airquality")

# %% [markdown]
# # Data structure

# %%
airquality.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 1   41.0    190.0   7.4    67      5    1
# 2   36.0    118.0   8.0    72      5    2
# 3   12.0    149.0  12.6    74      5    3
# 4   18.0    313.0  11.5    62      5    4
# 5    NaN      NaN  14.3    56      5    5

# %%
airquality.describe()
# Out:
#             Ozone     Solar.R        Wind        Temp       Month         Day
# count  116.000000  146.000000  153.000000  153.000000  153.000000  153.000000
# mean    42.129310  185.931507    9.957516   77.882353    6.993464   15.803922
# std     32.987885   90.058422    3.523001    9.465270    1.416522    8.864520
# min      1.000000    7.000000    1.700000   56.000000    5.000000    1.000000
# 25%     18.000000  115.750000    7.400000   72.000000    6.000000    8.000000
# 50%     31.500000  205.000000    9.700000   79.000000    7.000000   16.000000
# 75%     63.250000  258.750000   11.500000   85.000000    8.000000   23.000000
# max    168.000000  334.000000   20.700000   97.000000    9.000000   31.000000

# %%
airquality.tail()
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 149   30.0    193.0   6.9    70      9   26
# 150    NaN    145.0  13.2    77      9   27
# 151   14.0    191.0  14.3    75      9   28
# 152   18.0    131.0   8.0    76      9   29
# 153   20.0    223.0  11.5    68      9   30

# %%
airquality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 1 to 153
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    116 non-null    float64
#  1   Solar.R  146 non-null    float64
#  2   Wind     153 non-null    float64
#  3   Temp     153 non-null    int64
#  4   Month    153 non-null    int64
#  5   Day      153 non-null    int64
# dtypes: float64(3), int64(3)
# memory usage: 8.4 KB

# %%
 # airquality.selects()?

# %%
airquality.shape
# Out:
# (153, 6)

# %% [markdown]
# # Selecting columns/rows

# %%
airquality.iloc[3:5]
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 4   18.0    313.0  11.5    62      5    4
# 5    NaN      NaN  14.3    56      5    5

# %%
airquality.iloc[:,[3,4]]
# Out:
#      Temp  Month
# 1      67      5
# 2      72      5
# 3      74      5
# 4      62      5
# 5      56      5
# 6      66      5
# 7      65      5
# 8      59      5
# 9      61      5
# 10     69      5
# 11     74      5
# 12     69      5
# 13     66      5
# 14     68      5
# 15     58      5
# 16     64      5
# 17     66      5
# 18     57      5
# 19     68      5
# 20     62      5
# 21     59      5
# 22     73      5
# 23     61      5
# 24     61      5
# 25     57      5
# 26     58      5
# 27     57      5
# 28     67      5
# 29     81      5
# 30     79      5
# 31     76      5
# 32     78      6
# 33     74      6
# 34     67      6
# 35     84      6
# 36     85      6
# 37     79      6
# 38     82      6
# 39     87      6
# 40     90      6
# 41     87      6
# 42     93      6
# 43     92      6
# 44     82      6
# 45     80      6
# 46     79      6
# 47     77      6
# 48     72      6
# 49     65      6
# 50     73      6
# 51     76      6
# ...

# %%
airquality.loc[3:5]
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 3   12.0    149.0  12.6    74      5    3
# 4   18.0    313.0  11.5    62      5    4
# 5    NaN      NaN  14.3    56      5    5

# %% [markdown]
# # summary stats

# %%
airquality.nunique()
# Out:
# Ozone       67
# Solar.R    117
# Wind        31
# Temp        40
# Month        5
# Day         31
# dtype: int64

# %%
airquality.isna().sum()
# Out:
# Ozone      37
# Solar.R     7
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %%
airquality["Ozone"].isna().sum()
# Out:
# 37

# %%
airquality[["Ozone", "Solar.R"]].isna().sum()
# Out:
# Ozone      37
# Solar.R     7
# dtype: int64

# %%
airquality1=airquality.copy()

# %%
airquality1.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 1   41.0    190.0   7.4    67      5    1
# 2   36.0    118.0   8.0    72      5    2
# 3   12.0    149.0  12.6    74      5    3
# 4   18.0    313.0  11.5    62      5    4
# 5    NaN      NaN  14.3    56      5    5

# %%
airquality1["Ozone"].fillna(airquality1["Ozone"].median(),inplace=True)

# %%
airquality1["Ozone"].isna().sum()
# Out:
# 0

# %%
airquality1[["Ozone","Solar.R"]]
# Out:
#      Ozone  Solar.R
# 1     41.0    190.0
# 2     36.0    118.0
# 3     12.0    149.0
# 4     18.0    313.0
# 5     31.5      NaN
# 6     28.0      NaN
# 7     23.0    299.0
# 8     19.0     99.0
# 9      8.0     19.0
# 10    31.5    194.0
# 11     7.0      NaN
# 12    16.0    256.0
# 13    11.0    290.0
# 14    14.0    274.0
# 15    18.0     65.0
# 16    14.0    334.0
# 17    34.0    307.0
# 18     6.0     78.0
# 19    30.0    322.0
# 20    11.0     44.0
# 21     1.0      8.0
# 22    11.0    320.0
# 23     4.0     25.0
# 24    32.0     92.0
# 25    31.5     66.0
# 26    31.5    266.0
# 27    31.5      NaN
# 28    23.0     13.0
# 29    45.0    252.0
# 30   115.0    223.0
# 31    37.0    279.0
# 32    31.5    286.0
# 33    31.5    287.0
# 34    31.5    242.0
# 35    31.5    186.0
# 36    31.5    220.0
# 37    31.5    264.0
# 38    29.0    127.0
# 39    31.5    273.0
# 40    71.0    291.0
# 41    39.0    323.0
# 42    31.5    259.0
# 43    31.5    250.0
# 44    23.0    148.0
# ...

# %%
airquality1[["Ozone","Solar.R"]]
# Out:
#      Ozone  Solar.R
# 1     41.0    190.0
# 2     36.0    118.0
# 3     12.0    149.0
# 4     18.0    313.0
# 5     31.5      NaN
# 6     28.0      NaN
# 7     23.0    299.0
# 8     19.0     99.0
# 9      8.0     19.0
# 10    31.5    194.0
# 11     7.0      NaN
# 12    16.0    256.0
# 13    11.0    290.0
# 14    14.0    274.0
# 15    18.0     65.0
# 16    14.0    334.0
# 17    34.0    307.0
# 18     6.0     78.0
# 19    30.0    322.0
# 20    11.0     44.0
# 21     1.0      8.0
# 22    11.0    320.0
# 23     4.0     25.0
# 24    32.0     92.0
# 25    31.5     66.0
# 26    31.5    266.0
# 27    31.5      NaN
# 28    23.0     13.0
# 29    45.0    252.0
# 30   115.0    223.0
# 31    37.0    279.0
# 32    31.5    286.0
# 33    31.5    287.0
# 34    31.5    242.0
# 35    31.5    186.0
# 36    31.5    220.0
# 37    31.5    264.0
# 38    29.0    127.0
# 39    31.5    273.0
# 40    71.0    291.0
# 41    39.0    323.0
# 42    31.5    259.0
# 43    31.5    250.0
# 44    23.0    148.0
# ...

# %%
airquality1[["Ozone","Solar.R"]].notna()
# Out:
#      Ozone  Solar.R
# 1     True     True
# 2     True     True
# 3     True     True
# 4     True     True
# 5     True    False
# 6     True    False
# 7     True     True
# 8     True     True
# 9     True     True
# 10    True     True
# 11    True    False
# 12    True     True
# 13    True     True
# 14    True     True
# 15    True     True
# 16    True     True
# 17    True     True
# 18    True     True
# 19    True     True
# 20    True     True
# 21    True     True
# 22    True     True
# 23    True     True
# 24    True     True
# 25    True     True
# 26    True     True
# 27    True    False
# 28    True     True
# 29    True     True
# 30    True     True
# 31    True     True
# 32    True     True
# 33    True     True
# 34    True     True
# 35    True     True
# 36    True     True
# 37    True     True
# 38    True     True
# 39    True     True
# 40    True     True
# 41    True     True
# 42    True     True
# 43    True     True
# 44    True     True
# ...

# %%
airquality1.isin([31.5])
# Out:
#      Ozone  Solar.R   Wind   Temp  Month    Day
# 1    False    False  False  False  False  False
# 2    False    False  False  False  False  False
# 3    False    False  False  False  False  False
# 4    False    False  False  False  False  False
# 5     True    False  False  False  False  False
# 6    False    False  False  False  False  False
# 7    False    False  False  False  False  False
# 8    False    False  False  False  False  False
# 9    False    False  False  False  False  False
# 10    True    False  False  False  False  False
# 11   False    False  False  False  False  False
# 12   False    False  False  False  False  False
# 13   False    False  False  False  False  False
# 14   False    False  False  False  False  False
# 15   False    False  False  False  False  False
# 16   False    False  False  False  False  False
# 17   False    False  False  False  False  False
# 18   False    False  False  False  False  False
# 19   False    False  False  False  False  False
# ...

# %%
airquality1.isin([31.5]).sum()
# Out:
# Ozone      37
# Solar.R     0
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %% [markdown]
# # Filtering with conditions and ranges

# %%
airquality1[(airquality1["Ozone"]>30) & (airquality1["Solar.R"]<10)]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar.R, Wind, Temp, Month, Day]
# Index: []

# %%
(airquality1["Solar.R"]<10).sum()
# Out:
# 2

# %%
both=airquality1[(airquality1["Ozone"]>30) & (airquality1["Solar.R"]<10)]

# %%
both.shape
# Out:
# (0, 6)

# %%
airquality1["Ozone"].between(30,40).sum()
# Out:
# 53

# %% [markdown]
# # Sort function

# %%
airquality1.sort_values(by=["Ozone","Solar.R"],ascending=[True,False])
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 21     1.0      8.0   9.7    59      5   21
# 23     4.0     25.0   9.7    61      5   23
# 18     6.0     78.0  18.4    57      5   18
# 147    7.0     49.0  10.3    69      9   24
# 76     7.0     48.0  14.3    80      7   15
# 11     7.0      NaN   6.9    74      5   11
# 9      8.0     19.0  20.1    61      5    9
# 114    9.0     36.0  14.3    72      8   22
# 94     9.0     24.0  13.8    81      8    2
# 137    9.0     24.0  10.9    71      9   14
# 73    10.0    264.0  14.3    73      7   12
# 22    11.0    320.0  16.6    73      5   22
# 13    11.0    290.0   9.2    66      5   13
# 20    11.0     44.0   9.7    62      5   20
# 3     12.0    149.0  12.6    74      5    3
# 50    12.0    120.0  11.5    73      6   19
# 144   13.0    238.0  12.6    64      9   21
# 51    13.0    137.0  10.3    76      6   20
# 138   13.0    112.0  11.5    71      9   15
# 141   13.0     27.0  10.3    76      9   18
# ...

# %%
airquality1[airquality1["Ozone"].between(30,40)&(airquality1["Solar.R"].between(20,30))]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar.R, Wind, Temp, Month, Day]
# Index: []

# %% [markdown]
# # Duplicate

# %%
airquality1.duplicated().sum()
# Out:
# 0

# %%
airquality1.drop_duplicates(inplace=True)

# %% [markdown]
# # Derived columns arithmetic

# %%
df1=airquality1["Ozone"]*.2
df2=airquality["Solar.R"]/2

# %%
df1,df2
# Out:
# (1       8.2
#  2       7.2
#  3       2.4
#  4       3.6
#  5       6.3
#  6       5.6
#  7       4.6
#  8       3.8
#  9       1.6
#  10      6.3
#  11      1.4
#  12      3.2
#  13      2.2
#  14      2.8
#  15      3.6
#  16      2.8
#  17      6.8
#  18      1.2
#  19      6.0
#  20      2.2
#  21      0.2
#  22      2.2
#  23      0.8
#  24      6.4
#  25      6.3
#  26      6.3
#  27      6.3
#  28      4.6
#  29      9.0
#  30     23.0
#  31      7.4
#  32      6.3
#  33      6.3
#  34      6.3
#  35      6.3
#  36      6.3
#  37      6.3
#  38      5.8
#  39      6.3
#  40     14.2
#  41      7.8
#  42      6.3
#  43      6.3
#  44      4.6
#  45      6.3
#  46      6.3
#  47      4.2
#  48      7.4
#  49      4.0
#  50      2.4
#  51      2.6
#  52      6.3
#  53      6.3
#  54      6.3
#  55      6.3
#  56      6.3
#  57      6.3
#  58      6.3
#  59      6.3
#  60      6.3
#  61      6.3
#  62     27.0
#  63      9.8
#  64      6.4
#  65      6.3
#  66     12.8
# ...

# %%
df=df1-df2

# %%
df.describe()
# Out:
# count    146.000000
# mean     -85.054110
# std       43.630025
# min     -164.200000
# 25%     -121.000000
# 50%      -90.000000
# 75%      -53.025000
# max       -0.300000
# dtype: float64

# %% [markdown]
# # catgorization: pd.cut

# %%
import pandas as pd
bins=[0,20,40,60,80]
class1=["High","Medium","Low"]

# %%
new_df=pd.cut(df[["Ozone","Solar.R"]], bins=bins,class1=class1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21736\3188612065.py in <module>
# ----> 1 new_df=pd.cut(df[["Ozone","Solar.R"]], bins=bins,class1=class1)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     982             return self._get_values(key)
#     983
# --> 984         return self._get_with(key)
#     985
#     986     def _get_with(self, key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#    1022
#    1023         # handle the dup indexing case GH#4246
# -> 1024         return self.loc[key]
#    1025
#    1026     def _get_values_tuple(self, key):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# ...

# %%
new_df=pd.cut(df[[1,2]], bins=bins,class1=class1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21736\962815255.py in <module>
# ----> 1 new_df=pd.cut(df[[1,2]], bins=bins,class1=class1)
#
# TypeError: cut() got an unexpected keyword argument 'class1'

# %% [markdown]
# # Groupby & aggregation: agg, boolean-to-int counting

# %%
airquality1.groupby("Ozone").agg(total_ozone=(""))
